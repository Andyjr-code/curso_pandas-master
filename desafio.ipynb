# %% [markdown]
# # Análise Exporatória de Dados (EDA)

# %% [markdown]
# O SENAC ele possui um departamento de jogos. Qual o problema: com a mudança das gerações e perfil de jogadores, o time de jogos tem diversas dúvidas: que tipo de jogo é mais comercial , qual plataforma esta sendo mais utilizadal, que tipo de jogo podemos lançar (produto).

# %% [markdown]
# 1.   Entrar no Kaggle
# 2.   Escolher um DataSet
# 3.   Importar o pandas (carregar o dataset no google colab)
# 4.   Usar funções (head(), tail(),Series (tupla,lista,dict)),shape
# 5.   Estatística Descritiva: describe(), mostrar uma coluna, fatiar,columns, info(),len()
# 6.   Outras (loc(), iloc(),isnull(),fillna(),isna(),pivot(),drop(),lambda,mean(),median(),mode()

# %% [markdown]
# # Faça um relatório com a definição das variáveis (estatístico)

# %% [markdown]
# - Variável Quantitativa (contínua ou discreta)
# - Variável Qualitativa (nominal ou ordinal)

# %% [markdown]
# # 🎮 Análise de Dados de Videogames (1980 - 2023) 🕹️
#
# Este Colab Notebook é dedicado à exploração de um conjunto de dados fascinante que abrange a história dos videogames!
#
# ---
#
# ### 🌟 O Conteúdo do Conjunto de Dados
#
# Este *dataset* contém uma lista abrangente de videogames datados de **1980 a 2023**. Ele fornece informações valiosas para análise detalhada:
#
# * **📅 Datas de Lançamento:** A linha do tempo da indústria.
# * **⭐ Classificação de Avaliações de Usuários:** A nota média dada pela comunidade.
# * **🏆 Classificação de Avaliações Críticas:** A pontuação atribuída pela imprensa especializada.
#
# > **Nota:** Você encontrará não apenas os jogos populares e amplamente conhecidos, mas também aqueles **obscuros jogos indie** que esquecemos com o tempo!
#
# ---
#
# ### 💡 Inspiração: Backloggd
#
# A organização e exploração deste conjunto de dados reflete o espírito de plataformas como o **Backloggd**, que visa dar vida ao seu perfil de jogo.
#
# #### O que é o Backloggd?
#
# O Backloggd é um site de **coleção de videogames** misturado com elementos sociais, que permite aos usuários:
#
# 1.  **Registrar** os jogos que jogaram.
# 2.  **Classificar** e **revisar** seu progresso.
# 3.  **Detalhar** as jogatinas, incluindo plataformas, tempo jogado e até um **diário** para acompanhar o progresso diário.
#
# > **A Flexibilidade:** Tudo é adaptado ao quanto você deseja registrar, garantindo que o seu perfil se ajuste perfeitamente a você.
#
# #### Recursos Comunitários
#
# A plataforma também permite que você crie **listas de jogos**, adicione outros usuários como **amigos** e **siga** as suas atividades!
#
# ---
#
# ### 🚀 Começando no Colab
#
# Use o código abaixo para carregar e começar a explorar a vasta história dos jogos!

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/dataset_games.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # Análise de Linhas e Colunas

# %%
df.shape
# Out:
# (16598, 11)

# %% [markdown]
# *   Nosso dataset tem 1512 linhas e 14 colunas

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
